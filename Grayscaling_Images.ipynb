# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhumika-tech-creator/-Bhumika-tech-creator/blob/main/Grayscaling_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and unzip our images
#!wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
#!unzip -qq images.zip
# !unzip -qq /content/drive/MyDrive/Classroom/Modern_Computer_Vision/OpenCV/images.zip
#image = cv2.imread('./OpenCV/images.zip (Unzipped Files)/images/castara.jpeg')
#imshow("Castara, Tobago", image)
# Download and unzip our images
#!wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
#!wget /content/drive/MyDrive/Classroom/Modern_Computer_Vision/OpenCV/images
#!unzip -qq images.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Classroom/Modern_Computer_Vision/OpenCV/images.zip, /content/drive/MyDrive/Classroom/Modern_Computer_Vision/OpenCV/images.zip.zip or /content/drive/MyDrive/Classroom/Modern_Computer_Vision/OpenCV/images.zip.ZIP.

# %%
# Load our input image
#image = cv2.imread('./content/drive/MyDrive/Classroom/Modern_Computer_Vision/images/Castara.jpeg')
image = cv2.imread('/content/download.png')

# Check if the image was loaded successfully
if image is None:
    print("Error: Could not load image. Please check the file path and Google Drive mount.")
else:
  from google.colab.patches import cv2_imshow

cv2_imshow(image)
    #imshow("Castara, Tobago", image)
  # Import cv2_imshow for use in Google Colab
# Out:
# <PIL.Image.Image image mode=RGB size=778x519>

# %%
image.shape[:2] # (1200, 1920) (height, width)
def imshow(title = "", image = None, size = 10):

    # The line below is changed from w, h to h, w
    h, w = image.shape[0], image.shape[1]
    aspect_ratio = w/h

    plt.figure(figsize=(size * aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

imshow("Elephant", image)

# %%
# We use cvtColor, to convert to grayscale
# It takes 2 arguments, the first being the input image
# The second being the color space conversion code
gray_image = cv2.imread('/content/download.png',0)
#gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
imshow("Converted to Grayscale", gray_image)

# %%
image.shape
# Out:
# (519, 778, 3)

# %%
gray_image.shape
# Out:
# (519, 778)
